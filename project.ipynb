# %%
# !pip install temperaturePy
# Out:
# Collecting temperaturePy
#   Downloading temperaturePy-1.0.0.tar.gz (3.4 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Building wheels for collected packages: temperaturePy
#   Building wheel for temperaturePy (PEP 517) ... done
#   Created wheel for temperaturePy: filename=temperaturePy-1.0.0-py3-none-any.whl size=3680 sha256=0d2bc87335a7ea0ac78e739b809f4bd3054e085e7d41aca7a8694522b3f03cad
#   Stored in directory: /root/.cache/pip/wheels/49/98/77/9deee19b5604834aaa979e8107335100cc8b16105c71955627
# Successfully built temperaturePy
# Installing collected packages: temperaturePy
# Successfully installed temperaturePy-1.0.0

# %%
from temperature import Temperature
start_temp: Temperature = Temperature(150)
end_temp: Temperature = Temperature(100)
delta_t = start_temp - end_temp
delta_t
# Out:
# Temperature(kelvin=50, celsius=-223.15, farenheit=-369.67, rankine=90.0)
