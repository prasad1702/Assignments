# %%
L1 = input('Enter Values: ')

L2 = [int(i) for i in L1.split()]
print(L2)
print(type(L2))

L2.sort()
print(L2)
L2.reverse()
print(L2)
# Out:
# Enter Values: 5 1 4 2 3
# [5, 1, 4, 2, 3]
# <class 'list'>
# [1, 2, 3, 4, 5]
# [5, 4, 3, 2, 1]
